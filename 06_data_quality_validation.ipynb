-- %%
SELECT
    COUNT(*) AS total_rows,
    SUM(CASE WHEN fare_amount <= 0 THEN 1 ELSE 0 END) AS bad_fares,
    SUM(CASE WHEN trip_distance <= 0 THEN 1 ELSE 0 END) AS bad_distance
FROM nyc_taxi_silver;
