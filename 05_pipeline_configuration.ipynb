-- %%
CREATE OR REPLACE TABLE etl_pipeline_config AS
SELECT
    'nyc_taxi' AS pipeline_name,
    'samples.nyctaxi.trips' AS source_table,
    'nyc_taxi_bronze' AS bronze_table,
    'nyc_taxi_silver' AS silver_table,
    'nyc_taxi_gold_metrics' AS gold_table,
    true AS is_active;
